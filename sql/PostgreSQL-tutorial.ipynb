# %%
# %load_ext sql

import prettytable
prettytable.DEFAULT = "PLAIN_COLUMNS"

# %sql postgresql://postgres:844120@localhost:5432/ecommerceDB
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## list all tables available in db

# %%
# %%sql
#
# SELECT tablename FROM pg_tables WHERE schemaname = 'public';
# Out:
#  * postgresql://postgres:***@localhost:5432/ecommerceDB
# 7 rows affected.
# [('customers',),
#  ('orders',),
#  ('sellers',),
#  ('products',),
#  ('geolocations',),
#  ('order_items',),
#  ('payments',)]

# %% [markdown]
# ## list all columns present in table

# %%
# %%sql
#
# SELECT column_name
# FROM information_schema.columns
# WHERE table_name = 'orders';
# Out:
#  * postgresql://postgres:***@localhost:5432/ecommerceDB
# 8 rows affected.
# [('order_id',),
#  ('customer_id',),
#  ('order_status',),
#  ('order_purchase_timestamp',),
#  ('order_approved_at',),
#  ('order_delivered_carrier_date',),
#  ('order_delivered_customer_date',),
#  ('order_estimated_delivery_date',)]

# %% [markdown]
# **If you also want data types:**

# %%
# %%sql
#
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_name = 'orders';
# Out:
#  * postgresql://postgres:***@localhost:5432/ecommerceDB
# 8 rows affected.
# [('order_id', 'text'),
#  ('customer_id', 'text'),
#  ('order_status', 'text'),
#  ('order_purchase_timestamp', 'text'),
#  ('order_approved_at', 'text'),
#  ('order_delivered_carrier_date', 'text'),
#  ('order_delivered_customer_date', 'text'),
#  ('order_estimated_delivery_date', 'text')]

# %% [markdown]
# **If the table is in a different schema (e.g., public):**

# %%
# %%sql
#
# SELECT column_name
# FROM information_schema.columns
# WHERE table_name = 'orders'
# AND table_schema = 'public';
# Out:
#  * postgresql://postgres:***@localhost:5432/ecommerceDB
# 8 rows affected.
# [('order_id',),
#  ('customer_id',),
#  ('order_status',),
#  ('order_purchase_timestamp',),
#  ('order_approved_at',),
#  ('order_delivered_carrier_date',),
#  ('order_delivered_customer_date',),
#  ('order_estimated_delivery_date',)]

# %%
# Out:
#  * postgresql://postgres:***@localhost:5432/ecommerceDB
# 7 rows affected.
# [('customers',),
#  ('orders',),
#  ('sellers',),
#  ('products',),
#  ('geolocations',),
#  ('order_items',),
#  ('payments',)]
