# %% [markdown]
# # LINKED LIST

# %% [markdown]
# Resources: https://github.com/Radhika10128/Data_Structure

# %% [markdown]
# ### linked list implementation at compile time
#
# Basic implementation of linked list by adding newly created node at the end of the linked list.
#
# In this program we will be adding element of list at compile time.
#
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     } *head;
#
#     void showList();
#
#     int main()
#     {
#         head=(struct Node *)malloc(sizeof(struct Node));
#         printf("\n%p",head);
#
#         struct Node *n1=(struct Node *)malloc(sizeof(struct Node));
#         struct Node *n2=(struct Node *)malloc(sizeof(struct Node));
#         struct Node *n3=(struct Node *)malloc(sizeof(struct Node));
#         struct Node *n4=(struct Node *)malloc(sizeof(struct Node));
#
#         head->data=2;
#         head->next=n1;
#
#         n1->data=4;
#         n1->next=n2;
#
#         n2->data=6;
#         n2->next=n3;
#
#         n3->data=8;
#         n3->next=n4;
#
#         n4->data=10;
#         n4->next=NULL;
#         showList();
#
#         return 0;
#     }
#
#     void showList()
#     {
#         struct Node *temp=head;
#         printf("\n%p",temp);
#         printf("List: ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#     }

# %% [markdown]
# ### creating a linked list from user input
#
#     // adding element of list and the end of list
#
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head;
#
#
#     void createList(int size);
#     void showList();
#
#     int main()
#     {
#         int size, element;
#         printf("Enter size of list: ");
#         scanf("%d",&size);
#
#         createList(size);
#
#         return 0;
#     }
#     void createList(int size)
#     {
#         head=(struct Node *)malloc(sizeof(struct Node));
#         struct Node *temp; // to hold head for performing logic
#         int data;
#         if(head==NULL)
#         {
#             printf("Unable to allocate memory");
#             exit(0);
#         }
#
#         printf("Enter element: ");
#         scanf("%d",&data);
#
#         head->data=data;
#         head->next=NULL;
#         printf("List:  %d\n",head->data); // first node of list
#         temp=head; // storing head in temp so that we could not lose pointer to head
#
#         for(int i=1;i<size;i++)
#         {
#             struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#
#             if(newNode==NULL)
#             {
#                 printf("unable to allocate memory");
#                 exit(0);
#             }
#
#             printf("Enter element: ");
#             scanf("%d",&data);
#
#             newNode->data=data;
#             newNode->next=NULL;
#
#             temp->next=newNode; // linking previous node to new node
#             temp=temp->next; // making previous node as current node
#
#             showList();
#         }
#     }
#     void showList()
#     {
#         struct Node *temp;
#
#         if(head==NULL)
#         {
#             printf("List is empty");
#             exit(0);
#         }
#         temp=head;
#         printf("List: ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#         printf("\n");
#     }

# %% [markdown]
# ### creating a linked list from user input adding element of list and the end of list
#
# **slightly change in logic from previous approach**
#
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head=NULL;
#
#     void createList(int element);
#     void showList();
#
#     int main()
#     {
#         int size,element;
#         printf("Enter size: ");
#         scanf("%d",&size);
#         for(int i=0;i<size;i++)
#         {
#             printf("\nEnter element: ");
#             scanf("%d",&element);
#
#             createList(element);
#
#             showList();
#         }
#
#         return 0;
#     }
#
#     void createList(int element)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         struct Node *temp;
#
#         newNode->data=element;
#         newNode->next=NULL;
#         if(head==NULL)
#         {
#             head=newNode;
#             head->next=NULL;
#             return;
#         }
#         temp=head;
#         while(temp->next!=NULL)
#         {
#             temp=temp->next;
#         }
#
#         temp->next=newNode; // linking nodes
#
#     }
#
#     void showList() // another approach
#     {
#         struct Node *temp;
#         temp=head;
#         if(temp==NULL)
#         {
#             printf("List is empty");
#             return;
#         }
#         printf("List: ");
#         while(temp->next!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#         printf(" %d",temp->data);
#     }

# %% [markdown]
# ### inserting element at the begining of list
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#     struct Node *head; // declared globally
#
#     void insert(int element);
#     void display();
#
#     int main()
#     {
#         head=NULL;
#         int size, element;
#
#         printf("Enter size: ");
#         scanf("%d",&size);
#         for(int i=0;i<size;i++)
#         {
#             printf("Enter element: ");
#             scanf("%d",&element);
#
#             insert(element);
#             display();
#         }
#         return 0;
#     }
#
#     void insert(int element)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=element;
#         temp->next=head;
#
#         // we can replace line 38(temp->next=head) by below code as well
#             /*
#
#             temp->next=NULL;
#             if(head!=NULL)
#             {
#                 temp->next=head;
#             }
#
#             */
#
#         head=temp; // updating head
#     }
#
#     void display()
#     {
#         struct Node *temp;
#
#         if(head==NULL)
#         {
#             printf("List is empty");
#             exit(0);
#         }
#         temp=head;
#         printf("List: ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#         printf("\n");
#     }

# %% [markdown]
# ### inserting element at the begining of list by declaring `head as local variable`
#
#     // for that we will have to make certain chnages in all functions
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node *insert(struct Node *head, int element);
#     void display(struct Node *head);
#
#     int main()
#     {
#         struct Node *head=NULL;
#         int size, element;
#
#         printf("Enter size: ");
#         scanf("%d",&size);
#         for(int i=0;i<size;i++)
#         {
#             printf("Enter element: ");
#             scanf("%d",&element);
#
#             head=insert(head,element);
#             display(head);
#         }
#         return 0;
#     }
#
#     struct Node *insert(struct Node *head, int element)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=element;
#         temp->next=head;
#
#         // we can replace line 37 by below code as well
#             /*
#
#             temp->next=NULL;
#             if(head!=NULL)
#             {
#                 temp->next=head;
#             }
#
#             */
#
#         head=temp;
#         return head;
#     }
#
#     void display(struct Node *head)
#     {
#         if(head==NULL)
#         {
#             printf("List is empty");
#             exit(0);
#         }
#
#         printf("List: ");
#         while(head!=NULL)
#         {
#             printf(" %d",head->data);
#             head=head->next;
#         }
#         printf("\n");
#     }

# %% [markdown]
# ### inserting element at the begining of list by declaring head as local variable
#
#     // for that we will have to make certain chnages in all functions
#
# **// this time we will be passing reference to head to insert() function only**
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     void insert(struct Node **head, int element);
#     void display(struct Node *head);
#
#     int main()
#     {
#         struct Node *head=NULL;
#         int size, element;
#
#         printf("Enter size: ");
#         scanf("%d",&size);
#         for(int i=0;i<size;i++)
#         {
#             printf("Enter element: ");
#             scanf("%d",&element);
#
#             insert(&head,element);
#             display(head);
#         }
#         return 0;
#     }
#
#     void insert(struct Node **head, int element)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=element;
#         temp->next=*head;
#
#         // we can replace line 37 by below code as well
#         /*
#
#         temp->next=NULL;
#         if(*head!=NULL)
#         {
#             temp->next=*head;
#         }
#
#         */
#
#         *head=temp;
#     }
#
#     void display(struct Node *head)
#     {
#         if(head==NULL)
#         {
#             printf("List is empty");
#             exit(0);
#         }
#
#         printf("List: ");
#         while(head!=NULL)
#         {
#             printf(" %d",head->data);
#             head=head->next;
#         }
#         printf("\n");
#     }

# %% [markdown]
# ### counting total no. of nodes
#
#
#     int countNodes()
#     {
#         int count = 0;
#         struct Node *temp = head;
#         while (temp != NULL)
#         {
#             count++;
#             temp = temp->next;
#         }
#         return count;
#     }

# %% [markdown]
# ### inserting a node at nth position
#
#        // inserting a node at nth position
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head;
#     void insert(int data,int pos);
#     void print();
#     int main()
#     {
#         head=NULL;
#         insert(8,1); // 8
#         insert(12,2); // 8 12
#         insert(99,1); // 99 8 12
#         insert(44,2); // 99 44 8 12
#         print();
#
#         return 0;
#     }
#     void insert(int data, int pos)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         newNode->data=data;
#         newNode->next=NULL;
#
#         if(pos==1) // similar to inserting at begining
#         {
#             newNode->next=head;
#             head=newNode;
#             return;
#         }
#
#         struct Node *temp=head;// start at head
#
#         for(int i=0;i<(pos-2);i++) // go till (n-1)th position
#         {
#             temp=temp->next;
#         }// after end of loop temp will will be pointing to (n-1)th node
#
#         newNode->next=temp->next; // writing link part of (n-1)th node to link part of new node
#                                     // that is linking nth node with new node
#
#         temp->next=newNode; // writing address of new node to link part of nth node
#                             // that is linking (n-1)th node with new node
#     }
#     void print()
#     {
#         struct Node *temp=head;
#         if(head==NULL)
#         {
#             printf("List is empty\n");
#             exit(0);
#         }
#         printf("List : ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#     }

# %% [markdown]
# ### deleting  a node at nth position
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head;
#     void insert(int data,int pos);
#     void print();
#     void delete(int pos);
#     int main()
#     {
#         head=NULL;
#         insert(8,1); // 8
#         insert(12,2); // 8 12
#         insert(99,1); // 99 8 12
#         insert(44,2); // 99 44 8 12
#         print();
#
#         int pos;
#         printf("\nEnter the positon to delete: ");
#         scanf("%d",&pos);
#         delete(pos);
#         print();
#
#         return 0;
#     }
#     void insert(int data, int pos)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         newNode->data=data;
#         newNode->next=NULL;
#
#         if(pos==1) // similar to inserting at begining
#         {
#             newNode->next=head;
#             head=newNode;
#             return;
#         }
#
#         struct Node *temp=head; // start at head
#
#         for(int i=0;i<(pos-2);i++) // go till (n-1)th position
#         {
#             temp=temp->next;
#         }
#         // after end of loop temp will will be pointing to (n-1)th node
#
#         newNode->next=temp->next; // writing link part of (n-1)th node to link part of new node
#         temp->next=newNode; // writing address of new node to link part of (n-1)th node
#     }
#     void print()
#     {
#         struct Node *temp=head;
#         if(head==NULL)
#         {
#             printf("List is empty\n");
#             exit(0);
#         }
#         printf("List : ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#     }
#     void delete(int pos)
#     {
#         struct Node *temp1=head;
#         if(pos==1)
#         {
#             head=temp1->next;
#             free(temp1);
#             return;
#         }
#         for(int i=0;i<(pos-2);i++)
#         {
#             temp1=temp1->next;
#         }// after end of loop temp1 will be pointing (n-1)th node
#
#         struct Node *temp2=temp1->next; // now temp2 will be pointing nth node
#         temp1->next=temp2->next; //(n-1)th node
#         // writing link part of nth node to (n-1)th node which means detaching nth node
#         free(temp2);
#     }

# %% [markdown]
# ### delete node by key
#
#     // deleting  a node at nth position
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head;
#     void insert(int data,int pos);
#     void print();
#     void delete(int pos);
#     void deleteByKey(int key);
#     int main()
#     {
#         head=NULL;
#         insert(8,1); // 8
#         insert(12,2); // 8 12
#         insert(99,1); // 99 8 12
#         insert(44,2); // 99 44 8 12
#         print();
#
#         int key;
#         printf("\nEnter the key: ");
#         scanf("%d",&key);
#         deleteByKey(key);
#         print();
#
#         return 0;
#     }
#     void insert(int data, int pos)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         newNode->data=data;
#         newNode->next=NULL;
#
#         if(pos==1) // similar to inserting at begining
#         {
#             newNode->next=head;
#             head=newNode;
#             return;
#         }
#
#         struct Node *temp=head; // start at head
#
#         for(int i=0;i<(pos-2);i++) // go till (n-1)th position
#         {
#             temp=temp->next;
#         }// after end of loop temp will will be pointing to (n-1)th node
#
#         newNode->next=temp->next; // writing link part of (n-1)th node to link part of new node
#                                         // that is linking nth node with new node
#
#         temp->next=newNode; // writing address of new node to link part of nth node
#                                 // that is linking (n-1)th node with new node
#     }
#     void print()
#     {
#         struct Node *temp=head;
#         if(head==NULL)
#         {
#             printf("List is empty\n");
#             exit(0);
#         }
#         printf("List : ");
#         while(temp!=NULL)
#         {
#             printf(" %d",temp->data);
#             temp=temp->next;
#         }
#     }
#     void deleteByKey(int key)
#     {
#         struct Node *temp=head;
#         int pos=1;
#         while(temp!=NULL)
#         {
#             pos++;
#             temp=temp->next;
#             if(temp->data==key)
#             {
#                 delete(pos);
#                 break;
#             }
#         }
#         printf("\n key do not exist");
#     }
#     void delete(int pos)
#     {
#         struct Node *temp1=head;
#         if(pos==1)
#         {
#             head=temp1->next;
#             free(temp1);
#             return;
#         }
#         for(int i=0;i<(pos-2);i++)
#         {
#             temp1=temp1->next;
#         }// after end of loop temp1 will be pointing (n-1)th node
#
#         struct Node *temp2=temp1->next; // now temp2 will be pointing nth node
#         temp1->next=temp2->next; //(n-1)th node
#         // writing link part of nth node to (n-1)th node which means detaching nth node
#         free(temp2);
#     }

# %% [markdown]
# ### reverse linked list using iterative approach
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node *reverse(struct Node *head);
#     struct Node *insert(struct Node *head, int data);
#     void print(struct Node *head);
#
#     int main()
#     {
#         struct Node *head=NULL;
#
#         head=insert(head,2);
#         head=insert(head,7);
#         head=insert(head,3);
#         head=insert(head,1);
#         print(head);
#         head=reverse(head);
#         print(head);
#
#         return 0;
#     }
#     struct Node *reverse(struct Node *head)
#     {
#         struct Node *current, *previous, *nxt;
#         current=head;
#         previous=NULL;
#         while(current!=NULL)
#         {
#             nxt=current->next;
#             current->next=previous;
#             previous=current;
#             current=nxt;
#         }
#         head=previous;
#         return head;
#     }
#     struct Node *insert(struct Node *head,int data)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         newNode->data=data;
#         newNode->next=NULL;
#
#         if(head==NULL)
#         {
#             head=newNode;
#         }
#         else
#         {
#             struct Node *temp=head;
#             while(temp->next!=NULL)
#             {
#                 temp=temp->next;
#             }
#             temp->next=newNode;
#         }
#         return head;
#     }
#     void print(struct Node *head)
#     {
#         printf("\nList: ");
#         while(head!=NULL)
#         {
#             printf(" %d",head->data);
#             head=head->next;
#         }
#     }

# %% [markdown]
# ### print and reverse print linked list using recursion
#
#     // print linked list in reverse order using recursion (reverse print)
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node *insert(struct Node *head, int data);
#     void print(struct Node *head);
#     void reversePrint(struct Node *head);
#
#     int main()
#     {
#         struct Node *head=NULL;
#
#         head=insert(head,2);
#         head=insert(head,7);
#         head=insert(head,3);
#         head=insert(head,1);
#
#         printf("List: ");
#         print(head);
#
#         printf("\n");
#
#         printf("List: ");
#         reversePrint(head);
#
#         return 0;
#     }
#     struct Node *insert(struct Node *head,int data)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=data;
#         temp->next=NULL;
#
#         if(head==NULL)
#         {
#             head=temp;
#         }
#         else
#         {
#             struct Node *temp1=head;
#             while(temp1->next!=NULL)
#             {
#                 temp1=temp1->next;
#             }
#             temp1->next=temp;
#         }
#         return head;
#     }
#     void print(struct Node *head)
#     {
#         if(head==NULL)
#         {
#             return;
#         }
#         printf(" %d",head->data);
#         print(head->next);
#     }
#     void reversePrint(struct Node *head)
#     {
#         if(head==NULL)
#         {
#             return;
#         }
#         reversePrint(head->next);
#         printf(" %d",head->data);
#     }

# %% [markdown]
# ### reverse a linked list using recursion
#
#     // head as local variable
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node *reverse(struct Node *head);
#     void print(struct Node *head);
#     struct Node *insert(struct Node *head, int data);
#
#     int main()
#     {
#         struct Node *head=NULL;
#
#         head=insert(head,2);
#         head=insert(head,7);
#         head=insert(head,3);
#         head=insert(head,1);
#
#         printf("List: ");
#         print(head);
#
#         struct Node *reverseHead=reverse(head);
#
#         print(reverseHead);
#
#         return 0;
#     }
#     struct Node *insert(struct Node *head,int data)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=data;
#         temp->next=NULL;
#
#         if(head==NULL)
#         {
#             head=temp;
#         }
#         else
#         {
#             struct Node *temp1=head;
#             while(temp1->next!=NULL)
#             {
#                 temp1=temp1->next;
#             }
#             temp1->next=temp;
#         }
#         return head;
#     }
#
#     void print(struct Node *head)
#     {
#         printf("\nList: ");
#         while(head!=NULL)
#         {
#             printf(" %d",head->data);
#             head=head->next;
#         }
#     }
#     struct Node *reverse(struct Node *head)
#     {
#         if (head->next == NULL)
#         {
#             return head;
#         }
#
#         struct Node *reversed_rest = reverse(head->next);
#
#         // Reverse the head node and the rest of the linked list.
#         struct Node *temp=head->next;
#         temp->next=head;
#
#         /*
#
#         line 75 & 76 can be replace by single line of code:
#         head->next->next = head;
#
#         */
#         head->next = NULL;
#
#         // Return the reversed linked list.
#         return reversed_rest;
#     }

# %% [markdown]
# ### reverse a linked list using recursion (change in reverse() )
#
#     // slightly change in reverse() implementation logic
#
#     // head as local variable
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node* reverse(struct Node* head);
#
#     void print(struct Node* head);
#     struct Node* insert(struct Node* head, int data);
#
#     int main()
#     {
#         struct Node* head = NULL;
#
#         head = insert(head, 2);
#         head = insert(head, 7);
#         head = insert(head, 3);
#         head = insert(head, 1);
#
#         print(head);
#
#         head = reverse(head);
#
#         print(head); // printing reversed list
#
#         return 0;
#     }
#
#     struct Node* insert(struct Node* head, int data)
#     {
#         struct Node* temp = (struct Node*)malloc(sizeof(struct Node));
#         temp->data = data;
#         temp->next = NULL;
#
#         if (head == NULL)
#         {
#             head = temp;
#         }
#         else
#         {
#             struct Node* temp1 = head;
#             while (temp1->next != NULL)
#             {
#                 temp1 = temp1->next;
#             }
#             temp1->next = temp;
#         }
#         return head;
#     }
#
#     void print(struct Node* head)
#     {
#         printf("\nList: ");
#         while (head != NULL)
#         {
#             printf(" %d", head->data);
#             head = head->next;
#         }
#     }
#
#     struct Node* reverse(struct Node* head)
#     {
#         // Base case: if the list is empty or has only one node
#         if (head == NULL || head->next == NULL)
#         {
#             return head;
#         }
#
#         // Reverse the rest of the list
#         struct Node* reversed = reverse(head->next);
#
#         // Change the next pointer of the second last node to the current head
#         head->next->next = head;
#
#         // Set the next pointer of the current head to NULL
#         head->next = NULL;
#
#         // Return the new head of the reversed list
#         return reversed;
#     }

# %% [markdown]
# ### reverse a linked list using recursion (global head)
#
#     // head as global variable
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     }*head; // global
#
#     void reverse(struct Node *headPtr);
#     void print(struct Node *head);
#     struct Node *insert(struct Node *head, int data);
#
#     int main()
#     {
#         head=NULL;
#
#         head=insert(head,2);
#         head=insert(head,7);
#         head=insert(head,3);
#         head=insert(head,1);
#
#         print(head);
#
#         reverse(head);
#
#         print(head); // printing list again
#
#         return 0;
#     }
#     struct Node *insert(struct Node *head,int data)
#     {
#         struct Node *temp=(struct Node *)malloc(sizeof(struct Node));
#         temp->data=data;
#         temp->next=NULL;
#
#         if(head==NULL)
#         {
#             head=temp;
#         }
#         else
#         {
#             struct Node *temp1=head;
#             while(temp1->next!=NULL)
#             {
#                 temp1=temp1->next;
#             }
#             temp1->next=temp;
#         }
#         return head;
#     }
#
#     void print(struct Node *head)
#     {
#         printf("\nList: ");
#         while(head!=NULL)
#         {
#             printf(" %d",head->data);
#             head=head->next;
#         }
#     }
#     void reverse(struct Node *headPtr)
#     {
#         if(headPtr->next==NULL)
#         {
#             head=headPtr;
#             return;
#         }
#         reverse(headPtr->next);
#         struct Node *q=headPtr->next;
#         q->next=headPtr;
#         headPtr->next=NULL;
#     }

# %% [markdown]
# ### another approach to reverse linked list using recursion
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     void reverse(struct Node **headPtr);
#     void reverseRecursive(struct Node *current, struct Node *prev, struct Node **headPtr);
#     void print(struct Node *head);
#     struct Node *insert(struct Node *head, int data);
#
#     int main()
#     {
#         struct Node *head = NULL;
#
#         head = insert(head, 2);
#         head = insert(head, 7);
#         head = insert(head, 3);
#         head = insert(head, 1);
#
#         print(head);
#
#         reverse(&head);
#
#         print(head); // printing list again
#
#         return 0;
#     }
#
#     struct Node *insert(struct Node *head, int data)
#     {
#         struct Node *temp = (struct Node *)malloc(sizeof(struct Node));
#         temp->data = data;
#         temp->next = NULL;
#
#         if (head == NULL)
#         {
#             head = temp;
#         }
#         else
#         {
#             struct Node *temp1 = head;
#             while (temp1->next != NULL)
#             {
#                 temp1 = temp1->next;
#             }
#             temp1->next = temp;
#         }
#         return head;
#     }
#
#     void print(struct Node *head)
#     {
#         printf("\nList: ");
#         while (head != NULL)
#         {
#             printf(" %d", head->data);
#             head = head->next;
#         }
#     }
#
#     void reverse(struct Node **headPtr)
#     {
#         reverseRecursive(*headPtr, NULL, headPtr);
#     }
#
#     void reverseRecursive(struct Node *current, struct Node *prev, struct Node **headPtr)
#     {
#         if (current == NULL)
#         {
#             *headPtr = prev;
#             return;
#         }
#
#         struct Node *next = current->next;
#         current->next = prev;
#
#         reverseRecursive(next, current, headPtr);
#     }

# %% [markdown]
# ### doubly linked list
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#         struct Node *prev;
#     }*head;
#
#     void insertAtHead(int data);
#     struct Node *getNewNode(int data);
#     void print();
#     void reversePrint();
#
#     int main()
#     {
#         head=NULL;
#         insertAtHead(2);
#         print();
#         reversePrint();
#
#         insertAtHead(4);
#         print();
#         reversePrint();
#
#         insertAtHead(6);
#         print();
#         reversePrint();
#
#         insertAtHead(8);
#         print();
#         reversePrint();
#         return 0;
#     }
#     struct Node *getNewNode(int data)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#         newNode->data=data;
#         newNode->prev=NULL;
#         newNode->next=NULL;
#         return newNode;
#     }
#     void insertAtHead(int data)
#     {
#         struct Node *newNode=getNewNode(data);
#         if(head==NULL)
#         {
#             head=newNode;
#             return;
#         }
#         head->prev=newNode;
#         newNode->next=head;
#         head=newNode;
#     }
#     void insertAtTail(int data)
#     {
#         struct Node *temp=head;
#         struct Node *newNode=getNewNode(data);
#         if(head==NULL)
#         {
#             head=newNode;
#             return;
#         }
#         while(temp->next!=NULL)
#         {
#             temp=temp->next;
#         }
#         temp->next=newNode;
#         newNode->prev=temp;
#     }
#     void print()
#     {
#         struct Node *temp=head;
#         printf("froward: ");
#         while(temp!=NULL)
#         {
#             printf("%d ",temp->data);
#             temp=temp->next;
#         }
#         printf("\n");
#     }
#     void reversePrint()
#     {
#         struct Node *temp=head;
#         if(temp==NULL)
#         {
#             return;
#         }
#         while(temp->next!=NULL)
#         {
#             temp=temp->next;
#         }
#         printf("Revrse: ");
#         while(temp!=NULL)
#         {
#             printf("%d ",temp->data);
#             temp=temp->prev;
#         }
#         printf("\n");
#     }

# %% [markdown]
# # STACK

# %% [markdown]
# ### array based implementation of stack
#
#     #include<stdio.h>
#     #define MAX_SIZE 101
#     int arr[MAX_SIZE];
#     int top=-1;
#
#     void push(int x)
#     {
#         if(top==MAX_SIZE-1)
#         {
#             printf("Error: stack overflow");
#             return;
#         }
#         arr[++top]=x; // pushing element
#
#         /*
#
#         line 15 can be splitted into:
#         top++;
#         arr[top]=x;
#
#         */
#     }
#     void pop()
#     {
#         if(top==-1)
#         {
#             printf("\nError: no elements to pop");
#             return;
#         }
#         top--;
#     }
#     int top_element()
#     {
#         return arr[top];
#     }
#     void print()
#     {
#         if(top==-1)
#         {
#             printf("Stack is empty\n");
#         }
#         for(int i=0;i<=top;i++)
#         {
#             printf("%d\n",arr[i]);
#         }
#     }
#     int main()
#     {
#         push(2);
#         print();
#         pop();
#         print();
#         push(3);
#         push(4);
#         push(5);
#         print();
#         int topp=top_element();
#         printf("Top: %d",topp);
#         return 0;
#     }

# %% [markdown]
# ### linked list implementation of stack
#
#     #include <stdio.h>
#     #include <stdlib.h>
#
#     struct Node
#     {
#         int data;
#         struct Node *next;
#     };
#
#     struct Node *top=NULL;
#
#     void push(int data)
#     {
#         struct Node *newNode=(struct Node *)malloc(sizeof(struct Node));
#
#         newNode->data=data;
#         newNode->next=top;
#         top=newNode; // updating top to point new node
#     }
#     void pop()
#     {
#         struct Node *temp;
#         if(top==NULL)
#         {
#             printf("Stack is empty\n");
#             return;
#         }
#         temp=top; // making temp to point top element in stack
#         top=top->next; // making top to point next element as top
#         free(temp);
#     }
#     int top_element()
#     {
#         return top->data;
#     }
#     void print()
#     {
#         struct Node *temp=top;
#         while(temp!=NULL)
#         {
#             printf("%d ",temp->data);
#             temp=temp->next;
#         }
#     }
#     int main()
#     {
#         push(2);
#         print();
#         printf("\n");
#         push(3);
#         print();
#         printf("\n");
#         push(4);
#         print();
#         printf("\n");
#         pop();
#         print();
#         printf("\n");
#         int topp=top_element();
#         printf("Top: %d",topp);
#         return 0;
#     }

# %% [markdown]
# ### IsEmpty() pseudo code
#
#     IsEmpty()
#     {
#         if(top==-1)
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }

# %% [markdown]
# ### reverse a string using stack
#
#     // its TC=O(n)
#     // its SC=O(n)
#
#     // C++ program
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     void reverse(char *c, int n)
#     {
#         stack<char> s;
#         for(int i=0;i<n;i++) // O(n)
#         {
#             s.push(c[i]);
#         }
#         for(int i=0;i<n;i++) // O(n)
#         {
#             c[i]=s.top(); // inbuilt top()
#             s.pop(); // inbuilt pop()
#         }
#     }
#     int main()
#     {
#         char c[49];
#         printf("Enter String: ");
#         gets(c);
#         reverse(c,strlen(c));
#         printf("%s",c);
#     }

# %% [markdown]
# ### general approach to reverse a string in C
#
#     // its TC=O(n)
#     // its SC=O(1)
#
#     // C program
#     #include<stdio.h>
#     #include<string.h>
#     void reverse(char *str)
#     {
#         int len=strlen(str);
#         int temp;
#         for(int i=0;i<len/2;i++)
#         {
#             temp=str[i];
#             str[i]=str[len-i-1];
#             str[len-i-1]=temp;
#         }
#     }
#     int main()
#     {
#         char str[40];
#         printf("Enter String: ");
#         gets(str);
#         reverse(str);
#         printf("%s",str);
#
#         return 0;
#     }

# %% [markdown]
# ### reverse a linked list using stack
#
#     //C++ program
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     struct Node
#     {
#         int data;
#         Node *next;
#     }*head=NULL;
#
#     void showList();
#     void createList(int element);
#     void reverse();
#
#     int main()
#     {
#         int size,element;
#         cout<<"Enter size: ";
#         cin>>size;
#         for(int i=0;i<size;i++)
#         {
#             cout<<"\nEnter element: ";
#             cin>>element;
#
#             createList(element);
#
#             showList();
#         }
#         reverse();
#         showList();
#         return 0;
#     }
#     void createList(int element)
#     {
#         Node *newNode=new Node();
#         Node *temp;
#
#         newNode->data=element;
#         newNode->next=NULL;
#         if(head==NULL)
#         {
#             head=newNode;
#             head->next=NULL;
#             return;
#         }
#         temp=head;
#         while(temp->next!=NULL)
#         {
#             temp=temp->next;
#         }
#
#         temp->next=newNode; // linking nodes
#
#     }
#     void reverse()
#     {
#         if(head==NULL)
#         {
#             cout<<"\nList is empty.";
#             return;
#         }
#
#         stack <struct Node *>S; // explicit stack using STL
#
#         Node *temp=head;
#
#         while(temp!=NULL)
#         {
#             S.push(temp); // pushing each element to stack S
#             temp=temp->next; // making next node as current node
#         } // stack will contain address of each node
#
#         temp=S.top(); // temp is pointing to top element of stack
#         head=temp; // head is now pointing  to last node
#
#         S.pop(); // since head is pointing to last node by making use of top element in stack
#                 // then we need to remove top element from stack
#                 // so that we can adjust link of other nodes using stack element
#
#         while(!S.empty())
#         {
#             temp->next=S.top(); // reversing link
#             S.pop(); // since link is reversed, we need to remove top element to build revrse link for other nodes
#             temp=temp->next; // point to next node to build reverse link between nodes
#         }
#         temp->next=NULL; // pointing link part of last node to NULL
#     }
#     void showList()
#     {
#         Node *temp;
#         temp=head;
#         if(temp==NULL)
#         {
#             cout<<"List is empty"<<endl;
#             return;
#         }
#         cout<<"List: ";
#         while(temp->next!=NULL)
#         {
#             cout<<temp->data<<" ";
#             temp=temp->next;
#         }
#         cout<<temp->data<<" ";
#     }

# %% [markdown]
# ### check for balanced parentheses
#
#     //C++ program
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     // Function to check whether two characters are opening
#     // and closing of same type.
#     bool ArePair(char opening,char closing)
#     {
#         if(opening == '(' && closing == ')') return true;
#         else if(opening == '{' && closing == '}') return true;
#         else if(opening == '[' && closing == ']') return true;
#         return false;
#     }
#     bool AreParanthesesBalanced(string exp)
#     {
#         stack<char>  S;
#         for(int i =0;i<exp.length();i++)
#         {
#             if(exp[i] == '(' || exp[i] == '{' || exp[i] == '[')
#                 S.push(exp[i]);
#             else if(exp[i] == ')' || exp[i] == '}' || exp[i] == ']')
#             {
#                 if(S.empty() || !ArePair(S.top(),exp[i]))
#                     return false;
#                 else
#                     S.pop();
#             }
#         }
#         return S.empty() ? true:false;
#     }
#
#     int main()
#     {
#         /*Code to test the function AreParanthesesBalanced*/
#         string expression;
#         cout<<"Enter an expression:  "; // input expression from STDIN/Console
#         cin>>expression;
#         if(AreParanthesesBalanced(expression))
#             cout<<"Balanced\n";
#         else
#             cout<<"Not Balanced\n";
#     }

# %% [markdown]
# ### Evaluation Of postfix Expression in C++
#
#
#     // C++ program
#
#     #include <bits/stdc++.h>
#
#     using namespace std;
#
#     // Function to evaluate Postfix expression and return output
#     int EvaluatePostfix(string expression);
#
#     // Function to perform an operation and return output.
#     int PerformOperation(char operation, int operand1, int operand2);
#
#     // Function to verify whether a character is operator symbol or not.
#     bool IsOperator(char C);
#
#     // Function to verify whether a character is numeric digit.
#     bool IsNumericDigit(char C);
#
#     int main()
#     {
#         string expression;
#         cout<<"Enter Postfix Expression \n";
#         getline(cin,expression); //  Operands must be integers and there should be space in between two operands
#         int result = EvaluatePostfix(expression);
#         cout<<"Output = "<<result<<"\n";
#     }
#
#     // Function to evaluate Postfix expression and return output
#     int EvaluatePostfix(string expression)
#     {
#         // Declaring a Stack from Standard template library in C++.
#         stack<int> S;
#
#         for(int i = 0;i< expression.length();i++)
#         {
#
#             // Scanning each character from left.
#             // If character is a delimitter, move on.
#             if(expression[i] == ' ' || expression[i] == ',') continue;
#
#             // If character is operator, pop two elements from stack, perform operation and push the result back.
#             else if(IsOperator(expression[i]))
#             {
#                 // Pop two operands.
#                 int operand2 = S.top(); S.pop();
#                 int operand1 = S.top(); S.pop();
#                 // Perform operation
#                 int result = PerformOperation(expression[i], operand1, operand2);
#                 //Push back result of operation on stack.
#                 S.push(result);
#             }
#             else if(IsNumericDigit(expression[i]))
#             {
#                 // Extract the numeric operand from the string
#                 // Keep incrementing i as long as you are getting a numeric digit.
#                 int operand = 0;
#                 while(i<expression.length() && IsNumericDigit(expression[i]))
#                 {
#                     // For a number with more than one digits, as we are scanning from left to right.
#                     // Everytime , we get a digit towards right, we can multiply current total in operand by 10
#                     // and add the new digit.
#                     operand = (operand*10) + (expression[i] - '0');
#                     i++;
#                 }
#                 // Finally, you will come out of while loop with i set to a non-numeric character or end of string
#                 // decrement i because it will be incremented in increment section of loop once again.
#                 // We do not want to skip the non-numeric character by incrementing i twice.
#                 i--;
#
#                 // Push operand on stack.
#                 S.push(operand);
#             }
#         }
#         // If expression is in correct format, Stack will finally have one element. This will be the output.
#         return S.top();
#     }
#
#     // Function to verify whether a character is numeric digit.
#     bool IsNumericDigit(char C)
#     {
#         if(C >= '0' && C <= '9') return true;
#         return false;
#     }
#
#     // Function to verify whether a character is operator symbol or not.
#     bool IsOperator(char C)
#     {
#         if(C == '+' || C == '-' || C == '*' || C == '/')
#             return true;
#
#         return false;
#     }
#
#     // Function to perform an operation and return output.
#     int PerformOperation(char operation, int operand1, int operand2)
#     {
#         if(operation == '+') return operand1 +operand2;
#         else if(operation == '-') return operand1 - operand2;
#         else if(operation == '*') return operand1 * operand2;
#         else if(operation == '/') return operand1 / operand2;
#
#         else cout<<"Unexpected Error \n";
#         return -1;
#     }

# %% [markdown]
# # QUEUE

# %% [markdown]
# ### queue implementation using array
#
#     // this program have some limitation as empty spaces are wasted
#     // improved version in next program using circular array to avoid memory wastage
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     #define MAX_SIZE 5
#
#     int front=-1;
#     int rear=-1;
#     int arr[MAX_SIZE];
#
#     void Enqueue(int data);
#     void Dequeue();
#     bool isEmpty();
#     bool isFull();
#     void Print();
#
#     int main()
#     {
#         Dequeue();      cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(1);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(2);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(3);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(4);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(5);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(6);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(7);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Dequeue();	    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Dequeue();	    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(8);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(9);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(69);    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#     }
#     bool isFull()
#     {
#         if(rear==MAX_SIZE-1) // condtion for full
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#     bool isEmpty()
#     {
#         if(front==-1 && rear==-1) // condition for empty
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#     void Enqueue(int data)
#     {
#         cout<<"Enqueuing "<<data<<" \n";
#         if(isFull())
#         {
#             cout<<"Error: Queue is Full\n";
#             return;
#         }
#         else if(isEmpty()) // run on first enqueue
#         {
#             front=rear=0;
#         }
#         else
#         {
#             rear=rear+1; // update rear on second and further enqueue
#         }
#         arr[rear]=data; // writing enqueued data to array
#     }
#     void Dequeue()
#     {
#         cout<<"Dequeuing \n";
#         if(isEmpty())
#         {
#             cout<<"Error: Queue is Empty\n";
#             return;
#         }
#         else if(front==rear) // run when array has only one data
#         {
#             front=rear=-1;
#         }
#         else
#         {
#             front=front+1; // update front on every dequeue after first dequeue
#         }
#     }
#     void Print()
#     {
#         int queueSize=(rear-front)+1;
#         cout<<"Current size of Queue: "<<queueSize<<"  -----> ";
#
#         for(int i=front;i<=rear;i++)
#         {
#             cout<<arr[i]<<" ";
#         }
#         cout<<"\n\n";
#     }

# %% [markdown]
# ### queue implementation using circular array
#
#     // improved version of previous program using circular array to avoid memory wastage
#
#     #include<iostream>
#     using namespace std;
#     #define MAX_SIZE 5  //maximum size of the array that will store Queue.
#
#     int A[MAX_SIZE];
#     int front=-1;
#     int rear=-1;
#
#     bool IsEmpty()
#     {
#         return (front == -1 && rear == -1);
#     }
#     bool IsFull()
#     {
#         return (rear+1)%MAX_SIZE == front ? true : false;
#     }
#     void Enqueue(int x)
#     {
#         cout<<"Enqueuing "<<x<<" \n";
#         if(IsFull())
#         {
#             cout<<"Error: Queue is Full\n";
#             return;
#         }
#         if (IsEmpty())
#         {
#             front = rear = 0;
#         }
#         else
#         {
#             rear = (rear+1)%MAX_SIZE;
#         }
#         A[rear] = x;
#     }
#     void Dequeue()
#     {
#         cout<<"Dequeuing \n";
#         if(IsEmpty())
#         {
#             cout<<"Error: Queue is Empty\n";
#             return;
#         }
#         else if(front == rear )
#         {
#             rear = front = -1;
#         }
#         else
#         {
#             front = (front+1)%MAX_SIZE;
#         }
#     }
#     int Front() // Returns element at front of queue.
#     {
#         if(front == -1)
#         {
#             cout<<"Error: cannot return front from empty queue\n";
#             return -1;
#         }
#         return A[front];
#     }
#     void Print()
#     {
#         int queueSize = (rear+MAX_SIZE-front)%MAX_SIZE + 1;
#         cout<<"Current size of Queue: "<<queueSize<<"  -----> ";
#
#         for(int i = 0; i <queueSize; i++)
#         {
#             int index = (front+i) % MAX_SIZE; // Index of element while travesing circularly from front
#             cout<<A[index]<<" ";
#         }
#         cout<<"\n\n";
#     }
#     int main()
#     {
#         Dequeue();      cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(1);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(2);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(3);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(4);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(5);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(6);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(7);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Dequeue();	    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Dequeue();	    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(8);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#         Enqueue(9);     cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         Enqueue(69);    cout<<"Front: "<<front<<"  Rear: "<<rear<<endl;    Print();
#
#         cout<<"Front element: "<<Front()<<endl;
#     }

# %% [markdown]
# ### queue  implementation using Linked List
#
#     #include<stdio.h>
#     #include<stdlib.h>
#
#     struct Node {
#         int data;
#         struct Node* next;
#     };
#
#     // Two glboal variables to store address of front and rear nodes.
#     struct Node* front = NULL;
#     struct Node* rear = NULL;
#
#     // To Enqueue an integer
#     void Enqueue(int x)
#     {
#         struct Node* temp = (struct Node*)malloc(sizeof(struct Node));
#         temp->data =x;
#         temp->next = NULL;
#         if(front == NULL && rear == NULL)
#         {
#             front = rear = temp;
#             return;
#         }
#         rear->next = temp;
#         rear = temp;
#     }
#     void Dequeue()
#     {
#         struct Node* temp = front;
#         if(front == NULL)
#         {
#             printf("Queue is Empty\n");
#             return;
#         }
#         if(front == rear)
#         {
#             front = rear = NULL;
#         }
#         else
#         {
#             front = front->next;
#         }
#         free(temp);
#     }
#     int Front()
#     {
#         if(front == NULL)
#         {
#             printf("Queue is empty\n");
#             return;
#         }
#         return front->data;
#     }
#     void Print()
#     {
#         struct Node* temp = front;
#         while(temp != NULL)
#         {
#             printf("%d ",temp->data);
#             temp = temp->next;
#         }
#         printf("\n");
#     }
#     int main()
#     {
#         Enqueue(2); Print();
#         Enqueue(4); Print();
#         Enqueue(6); Print();
#         Dequeue();  Print();
#         Enqueue(8); Print();
#     }

# %% [markdown]
# # TREE

# %% [markdown]
# ### Binary Search Tree Implemenation in C++
#
#     #include<iostream>
#     using namespace std;
#
#     struct BstNode
#     {
#         int data;
#         BstNode* left; // left child
#         BstNode* right; // right child
#     };
#
#     // Function to create a new Node in heap
#     BstNode* GetNewNode(int data)
#     {
#         BstNode* newNode = new BstNode();
#         newNode->data = data;
#         newNode->left = newNode->right = NULL;
#         return newNode;
#     }
#
#     // To insert data in BST, returns address of root node
#     BstNode* Insert(BstNode* root,int data)
#     {
#         if(root == NULL)// empty tree
#         {
#             root = GetNewNode(data);
#         }
#         else if(data <= root->data)// if data to be inserted is lesser, insert in left subtree.
#         {
#             root->left = Insert(root->left,data);
#         }
#         else	// else, insert in right subtree.
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#     //To search an element in BST, returns true if element is found
#     bool Search(BstNode* root,int data)
#     {
#         if(root == NULL)
#         {
#             return false;
#         }
#         else if(root->data == data)
#         {
#             return true;
#         }
#         else if(data <= root->data)
#         {
#             return Search(root->left,data);
#         }
#         else
#         {
#             return Search(root->right,data);
#         }
#     }
#     int main()
#     {
#         BstNode* root = NULL;  // Creating an empty tree
#
#         root = Insert(root,15);
#         root = Insert(root,10);
#         root = Insert(root,20);
#         root = Insert(root,25);
#         root = Insert(root,8);
#         root = Insert(root,12);
#
#         int number;
#         cout<<"Enter number be searched\n";
#         cin>>number;
#
#         if(Search(root,number) == true)
#         {
#             cout<<"Found\n";
#         }
#         else
#         {
#             cout<<"Not found\n";
#         }
#     }

# %% [markdown]
# ### iterative approach to find min/max in BST
#
#     #include<iostream>
#     using namespace std;
#
#     struct BstNode
#     {
#         int data;
#         BstNode* left; // left child
#         BstNode* right; // right child
#     };
#
#     // Function to create a new Node in heap
#     BstNode* GetNewNode(int data)
#     {
#         BstNode* newNode = new BstNode();
#         newNode->data = data;
#         newNode->left = newNode->right = NULL;
#         return newNode;
#     }
#
#     // To insert data in BST, returns address of root node
#     BstNode* Insert(BstNode* root,int data)
#     {
#         if(root == NULL)// empty tree
#         {
#             root = GetNewNode(data);
#         }
#         else if(data <= root->data)// if data to be inserted is lesser, insert in left subtree.
#         {
#             root->left = Insert(root->left,data);
#         }
#         else	// else, insert in right subtree.
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#
#     int findMin(BstNode *root)
#     {
#         if(root==NULL)
#         {
#             cout<<"Tree is empty"<<endl;
#             return -1;
#         }
#         while(root->left!=NULL)
#         {
#             root=root->left;
#         }
#         return root->data;
#     }
#     int findMax(BstNode *root)
#     {
#         if(root==NULL)
#         {
#             cout<<"Tree is empty"<<endl;
#             return -1;
#         }
#         while(root->right!=NULL)
#         {
#             root=root->right;
#         }
#         return root->data;
#     }
#     int main()
#     {
#         BstNode* root = NULL;  // Creating an empty tree
#
#         root = Insert(root,15);
#         root = Insert(root,10);
#         root = Insert(root,20);
#         root = Insert(root,25);
#         root = Insert(root,8);
#         root = Insert(root,12);
#
#         cout<<"Min: "<<findMin(root)<<" Max: "<<findMax(root)<<endl;
#     }

# %% [markdown]
# ### recursive approach to find min/max in BST
#
#     #include<iostream>
#     using namespace std;
#
#     struct BstNode
#     {
#         int data;
#         BstNode* left; // left child
#         BstNode* right; // right child
#     };
#
#     // Function to create a new Node in heap
#     BstNode* GetNewNode(int data)
#     {
#         BstNode* newNode = new BstNode();
#         newNode->data = data;
#         newNode->left = newNode->right = NULL;
#         return newNode;
#     }
#
#     // To insert data in BST, returns address of root node
#     BstNode* Insert(BstNode* root,int data)
#     {
#         if(root == NULL)// empty tree
#         {
#             root = GetNewNode(data);
#         }
#         else if(data <= root->data)// if data to be inserted is lesser, insert in left subtree.
#         {
#             root->left = Insert(root->left,data);
#         }
#         else	// else, insert in right subtree.
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#
#     int findMin(BstNode *root)
#     {
#         if(root==NULL)
#         {
#             cout<<"Tree is empty"<<endl;
#             return -1;
#         }
#         else if(root->left==NULL)
#         {
#             return root->data;
#         }
#         return findMin(root->left);
#     }
#     int findMax(BstNode *root)
#     {
#         if(root==NULL)
#         {
#             cout<<"Tree is empty"<<endl;
#             return -1;
#         }
#         else if(root->right==NULL)
#         {
#             return root->data;
#         }
#         return findMax(root->right);
#     }
#     int main()
#     {
#         BstNode* root = NULL;  // Creating an empty tree
#
#         root = Insert(root,15);
#         root = Insert(root,10);
#         root = Insert(root,20);
#         root = Insert(root,25);
#         root = Insert(root,8);
#         root = Insert(root,12);
#
#         cout<<"Min: "<<findMin(root)<<" Max: "<<findMax(root)<<endl;
#     }

# %% [markdown]
# ### find height of Binary Tree
#
#     #include<iostream>
#     using namespace std;
#
#     struct BstNode
#     {
#         int data;
#         BstNode* left; // left child
#         BstNode* right; // right child
#     };
#
#     // Function to create a new Node in heap
#     BstNode* GetNewNode(int data)
#     {
#         BstNode* newNode = new BstNode();
#         newNode->data = data;
#         newNode->left = newNode->right = NULL;
#         return newNode;
#     }
#
#     // To insert data in BST, returns address of root node
#     BstNode* Insert(BstNode* root,int data)
#     {
#         if(root == NULL)// empty tree
#         {
#             root = GetNewNode(data);
#         }
#         else if(data <= root->data)// if data to be inserted is lesser, insert in left subtree.
#         {
#             root->left = Insert(root->left,data);
#         }
#         else	// else, insert in right subtree.
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#     int findHeight(BstNode *root)
#     {
#         if(root==NULL)
#         {
#             return -1;
#         }
#         int leftHeight=findHeight(root->left);
#         int rightHeight=findHeight(root->right);
#
#         return max(leftHeight,rightHeight)+1;
#     }
#     int main()
#     {
#         BstNode* root = NULL;  // Creating an empty tree
#
#         root = Insert(root,15);
#         root = Insert(root,10);
#         root = Insert(root,20);
#         root = Insert(root,25);
#         root = Insert(root,8);
#         root = Insert(root,12);
#
#         cout<<"height of Binary tree: "<<findHeight(root)<<endl;
#     }

# %% [markdown]
# ### Level Order Traversal or breadth first traversal of binary tree
#
#     #include<iostream>
#     #include<queue>
#     using namespace std;
#
#     struct Node
#     {
#         char data;
#         Node *left;
#         Node *right;
#     };
#
#
#     void LevelOrder(Node *root) // Function to print Nodes in a binary tree in Level order
#     {
#         if(root == NULL)
#         {
#             return;
#         }
#
#         queue<Node*> Q;
#
#         Q.push(root);
#
#         while(!Q.empty()) //while there is at least one discovered node
#         {
#             Node* current = Q.front();
#             Q.pop(); // removing the element at front
#             cout<<current->data<<" ";
#
#             if(current->left != NULL) Q.push(current->left);
#             if(current->right != NULL) Q.push(current->right);
#         }
#     }
#
#     Node* Insert(Node *root,char data) // Function to Insert Node in a Binary Search Tree
#     {
#         if(root == NULL)
#         {
#             root = new Node();
#             root->data = data;
#             root->left = root->right = NULL;
#         }
#         else if(data <= root->data) root->left = Insert(root->left,data);
#         else root->right = Insert(root->right,data);
#         return root;
#     }
#
#     int main()
#     {
#
#         Node* root = NULL;
#         root = Insert(root,'M'); root = Insert(root,'B');
#         root = Insert(root,'Q'); root = Insert(root,'Z');
#         root = Insert(root,'A'); root = Insert(root,'C');
#         //Print Nodes in Level Order.
#         LevelOrder(root);
#     }
#     /*Code To Test the logic
#           Creating an example tree
#                     M
#                    / \
#                   B   Q
#                  / \   \
#                 A   C   Z
#         */

# %% [markdown]
# ### Binary Tree Traversal - Preorder, Inorder, Postorder
#
#     #include<iostream>
#     using namespace std;
#
#     struct Node
#     {
#         char data;
#         struct Node *left;
#         struct Node *right;
#     };
#
#     void Preorder(struct Node *root)
#     {
#         // base condition for recursion
#         // if tree/sub-tree is empty, return and exit
#         if(root == NULL)
#         {
#             return;
#         }
#         printf("%c ",root->data); // Print data
#         Preorder(root->left);     // Visit left subtree
#         Preorder(root->right);    // Visit right subtree
#     }
#
#     //Function to visit nodes in Inorder
#     void Inorder(Node *root)
#     {
#         if(root == NULL)
#         {
#             return;
#         }
#         Inorder(root->left);       //Visit left subtree
#         printf("%c ",root->data);  //Print data
#         Inorder(root->right);      // Visit right subtree
#     }
#
#     //Function to visit nodes in Postorder
#     void Postorder(Node *root)
#     {
#         if(root == NULL)
#         {
#             return;
#         }
#         Postorder(root->left);    // Visit left subtree
#         Postorder(root->right);   // Visit right subtree
#         printf("%c ",root->data); // Print data
#     }
#
#     // Function to Insert Node in a Binary Search Tree
#     Node* Insert(Node *root,char data)
#     {
#         // If tree is empty, create a new node and return it
#         if(root == NULL)
#         {
#             root = new Node();
#             root->data = data;
#             root->left = root->right = NULL;
#         }
#         else if(data <= root->data)
#         {
#             root->left = Insert(root->left,data);
#         }
#         else
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#
#     int main()
#     {
#         Node* root = NULL;
#         root = Insert(root,'M'); root = Insert(root,'B');
#         root = Insert(root,'Q'); root = Insert(root,'Z');
#         root = Insert(root,'A'); root = Insert(root,'C');
#         //Print Nodes in Preorder.
#         cout<<"Preorder: ";
#         Preorder(root);
#         cout<<"\n";
#         //Print Nodes in Inorder
#         cout<<"Inorder: ";
#         Inorder(root);
#         cout<<"\n";
#         //Print Nodes in Postorder
#         cout<<"Postorder: ";
#         Postorder(root);
#         cout<<"\n";
#     }
#     /*Code To Test the logic
#           Creating an example tree
#                     M
#                    / \
#                   B   Q
#                  / \   \
#                 A   C   Z
#         */

# %% [markdown]
# ### check given binary tree is BST
#
#     // does not allow duplicates
#     // TC=O(n^2)
#
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     struct Node
#     {
#         int data;
#         Node *left;
#         Node *right;
#     };
#     bool isSubtreeGreater(Node *root,int value)
#     {
#         if(root==NULL)
#         {
#             return true;
#         }
#         if(root->data>value && isSubtreeGreater(root->left,value) && isSubtreeGreater(root->right,value))
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#     bool isSubtreeLesser(Node *root,int value)
#     {
#         if(root==NULL)
#         {
#             return true;
#         }
#         if(root->data<=value && isSubtreeLesser(root->left,value) && isSubtreeLesser(root->right,value))
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#     bool isBst(Node *root)
#     {
#         if(root==NULL)
#         {
#             return true;
#         }
#         if(isSubtreeLesser(root->left,root->data) && isSubtreeGreater(root->right,root->data) && isBst(root->left) && isBst(root->right))
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#
#     Node* newNode(int data)
#     {
#         Node* node = new Node();
#         node->data = data;
#         node->left = NULL;
#         node->right = NULL;
#         return node;
#     }
#
#     int main()
#     {
#         Node *root = newNode(10);
#         root->left = newNode(5);
#         root->right = newNode(16);
#         root->left->left = newNode(4);
#         root->left->right = newNode(7);
#         root->left->left->left = newNode(1);
#         root->left->right->right = newNode(11);
#         root->left->right->left = newNode(9);
#
#
#
#
#         if (isBst(root))
#             cout << "BST" << endl;
#         else
#             cout << "Not a BST" << endl;
#
#         return 0;
#     }

# %% [markdown]
# ### check given binary tree is BST
#
#     // does not allow duplicates
#     // TC=O(n)
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     struct Node
#     {
#         int data;
#         Node *left;
#         Node *right;
#     };
#
#     bool isBstUtil(Node *root, int minVal, int maxVal)
#     {
#         if(root == NULL)
#         {
#             return true;
#         }
#
#         if(root->data > minVal && root->data < maxVal && isBstUtil(root->left, minVal, root->data) && isBstUtil(root->right, root->data, maxVal))
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#
#     bool isBst(Node *root)
#     {
#         return isBstUtil(root, INT_MIN, INT_MAX);
#     }
#
#     Node* newNode(int data)
#     {
#         Node* node = new Node();
#         node->data = data;
#         node->left = NULL;
#         node->right = NULL;
#         return node;
#     }
#
#     int main()
#     {
#         Node *root = newNode(5);
#         root->left = newNode(1);
#         root->right = newNode(8);
#         root->right->left = newNode(9);
#         root->right->right = newNode(12);
#
#         if (isBst(root))
#             cout << "BST" << endl;
#         else
#             cout << "Not a BST" << endl;
#
#         return 0;
#     }

# %% [markdown]
# ### check given binary tree is BST
#
#     // allow duplicates
#     // TC=O(n)
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     struct Node
#     {
#         int data;
#         Node *left;
#         Node *right;
#     };
#
#     bool isBstUtil(Node *root, int minVal, int maxVal)
#     {
#         if(root == NULL)
#         {
#             return true;
#         }
#
#         if(root->data >= minVal && root->data <= maxVal && isBstUtil(root->left, minVal, root->data) && isBstUtil(root->right, root->data, maxVal))
#         {
#             return true;
#         }
#         else
#         {
#             return false;
#         }
#     }
#
#     bool isBst(Node *root)
#     {
#         return isBstUtil(root, INT_MIN, INT_MAX);
#     }
#
#     Node* newNode(int data)
#     {
#         Node* node = new Node();
#         node->data = data;
#         node->left = NULL;
#         node->right = NULL;
#         return node;
#     }
#
#     int main()
#     {
#         Node *root = newNode(10);
#         root->left = newNode(5);
#         root->right = newNode(16);
#         root->left->left = newNode(4);
#         root->left->right = newNode(7);
#         root->left->left->left = newNode(1);
#         root->left->right->right = newNode(11);
#         root->left->right->left = newNode(7);
#
#         if (isBst(root))
#             cout << "BST" << endl;
#         else
#             cout << "Not a BST" << endl;
#
#         return 0;
#     }

# %% [markdown]
# ### check given binary tree is BST (another approach)
#
#     // allow duplicates
#     // TC=O(n)
#
#     #include<bits/stdc++.h>
#     using namespace std;
#
#     struct Node
#     {
#         int data;
#         Node *left;
#         Node *right;
#     };
#
#     int isBSTUtil(Node* node, int min, int max);
#
#     /*
#      * Returns true if the given tree is a binary search tree
#      */
#     int isBST(Node* node)
#     {
#         return(isBSTUtil(node, INT_MIN, INT_MAX));
#     }
#
#     /*
#      * Returns true if the given tree is a BST and its
#      * values are >= min and <= max.
#      */
#     int isBSTUtil(struct Node* node, int min, int max)
#     {
#         if (node==NULL)
#             return true;
#         if (node->data < min || node->data > max)
#             return false;
#         return isBSTUtil(node->left, min, node->data - 1) &&  isBSTUtil(node->right, node->data + 1, max);
#     }
#
#     Node* newNode(int data)
#     {
#         Node* node = new Node();
#         node->data = data;
#         node->left = NULL;
#         node->right = NULL;
#         return node;
#     }
#
#     int main()
#     {
#         Node *root = newNode(10);
#         root->left = newNode(5);
#         root->right = newNode(16);
#         root->left->left = newNode(4);
#         root->left->right = newNode(7);
#         root->left->left->left = newNode(1);
#         root->left->right->right = newNode(11);
#         root->left->right->left = newNode(7);
#
#         if (isBST(root))
#             cout << "BST" << endl;
#         else
#             cout << "Not a BST" << endl;
#
#         return 0;
#     }

# %% [markdown]
# ### Deleting a node from Binary search tree
#
#     #include<iostream>
#     using namespace std;
#     struct Node
#     {
#         int data;
#         struct Node *left;
#         struct Node *right;
#     };
#     //Function to find minimum in a tree.
#     Node* FindMin(Node* root)
#     {
#         while(root->left != NULL)
#         {
#             root = root->left;
#         }
#         return root;
#     }
#
#     // Function to search a delete a value from tree.
#     struct Node* Delete(struct Node *root, int data)
#     {
#         if(root == NULL)
#         {
#             return root;
#         }
#         else if(data < root->data)
#         {
#             root->left = Delete(root->left,data);
#         }
#         else if (data > root->data)
#         {
#             root->right = Delete(root->right,data);
#         }
#         // Wohoo... I found you, Get ready to be deleted
#         else {
#             // Case 1:  No child
#             if(root->left == NULL && root->right == NULL)
#             {
#                 delete root;
#                 root = NULL;
#             }
#             //Case 2: One child
#             else if(root->left == NULL)
#             {
#                 struct Node *temp = root;
#                 root = root->right;
#                 delete temp;
#             }
#             else if(root->right == NULL)
#             {
#                 struct Node *temp = root;
#                 root = root->left;
#                 delete temp;
#             }
#             // case 3: 2 children
#             else
#             {
#                 struct Node *temp = FindMin(root->right);
#                 root->data = temp->data;
#                 root->right = Delete(root->right,temp->data);
#             }
#         }
#         return root;
#     }
#
#     //Function to visit nodes in Inorder
#     void Inorder(Node *root)
#     {
#         if(root == NULL)
#         {
#             return;
#         }
#
#         Inorder(root->left);       //Visit left subtree
#         printf("%d ",root->data);  //Print data
#         Inorder(root->right);      // Visit right subtree
#     }
#
#     // Function to Insert Node in a Binary Search Tree
#     Node* Insert(Node *root,char data)
#     {
#         if(root == NULL)
#         {
#             root = new Node();
#             root->data = data;
#             root->left = root->right = NULL;
#         }
#         else if(data <= root->data)
#         {
#             root->left = Insert(root->left,data);
#         }
#         else
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#
#     int main()
#     {
#         Node* root = NULL;
#         root = Insert(root,5); root = Insert(root,10);
#         root = Insert(root,3); root = Insert(root,4);
#         root = Insert(root,1); root = Insert(root,11);
#
#         // Deleting node with value 5, change this value to test other cases
#         root = Delete(root,5);
#
#         //Print Nodes in Inorder
#         cout<<"Inorder: ";
#         Inorder(root);
#         cout<<"\n";
#     }

# %% [markdown]
# ### find Inorder successor in a BST
#
#
#     #include<iostream>
#     using namespace std;
#     struct Node
#     {
#         int data;
#         struct Node *left;
#         struct Node *right;
#     };
#
#     //Function to find some data in the tree
#     Node* Find(Node*root, int data)
#     {
#         if(root == NULL)
#         {
#             return NULL;
#         }
#         else if(root->data == data)
#         {
#             return root;
#         }
#         else if(root->data < data)
#         {
#             return Find(root->right,data);
#         }
#         else
#         {
#             return Find(root->left,data);
#         }
#     }
#
#     //Function to find Node with minimum value in a BST
#     struct Node* FindMin(struct Node* root)
#     {
#         if(root == NULL)
#         {
#             return NULL;
#         }
#         while(root->left != NULL)
#         {
#             root = root->left;
#         }
#         return root;
#     }
#
#     //Function to find Inorder Successor in a BST
#     struct Node* Getsuccessor(struct Node* root,int data)
#     {
#         // Search the Node - O(h)
#         struct Node* current = Find(root,data);
#         if(current == NULL)
#         {
#             return NULL;
#         }
#         if(current->right != NULL) //Case 1: Node has right subtree
#         {
#             return FindMin(current->right); // O(h)
#         }
#         else //Case 2: No right subtree  - O(h)
#         {
#             struct Node* successor = NULL;
#             struct Node* ancestor = root;
#             while(ancestor != current)
#             {
#                 if(current->data < ancestor->data)
#                 {
#                     successor = ancestor; // so far this is the deepest node for which current node is in left
#                     ancestor = ancestor->left;
#                 }
#                 else
#                 {
#                     ancestor = ancestor->right;
#                 }
#             }
#             return successor;
#         }
#     }
#
#     //Function to visit nodes in Inorder
#     void Inorder(Node *root)
#     {
#         if(root == NULL)
#         {
#             return;
#         }
#
#         Inorder(root->left);       //Visit left subtree
#         printf("%d ",root->data);  //Print data
#         Inorder(root->right);      // Visit right subtree
#     }
#
#     // Function to Insert Node in a Binary Search Tree
#     Node* Insert(Node *root,char data)
#     {
#         if(root == NULL)
#         {
#             root = new Node();
#             root->data = data;
#             root->left = root->right = NULL;
#         }
#         else if(data <= root->data)
#         {
#             root->left = Insert(root->left,data);
#         }
#         else
#         {
#             root->right = Insert(root->right,data);
#         }
#         return root;
#     }
#     int main()
#     {
#
#         Node* root = NULL;
#         root = Insert(root,5); root = Insert(root,10);
#         root = Insert(root,3); root = Insert(root,4);
#         root = Insert(root,1); root = Insert(root,11);
#
#         //Print Nodes in Inorder
#         cout<<"Inorder Traversal: ";
#         Inorder(root);
#         cout<<"\n";
#
#         // Find Inorder successor of some node.
#         struct Node* successor = Getsuccessor(root,1);
#         if(successor == NULL)
#         {
#             cout<<"No successor Found\n";
#         }
#         else
#         {
#             cout<<"Successor is "<<successor->data<<"\n";
#         }
#     }

# %% [markdown]
# // to find Inorder successor in a BST
# // we have reference to parent as well
# #include<iostream>
# using namespace std;
#
# struct Node {
#     int data;
#     Node* left;
#     Node* right;
#     Node* parent;
# };
#
# // Function to find some data in the tree
# Node* Find(Node* root, int data) {
#     if (root == NULL)
#         return NULL;
#     else if (root->data == data)
#         return root;
#     else if (root->data < data)
#         return Find(root->right, data);
#     else
#         return Find(root->left, data);
# }
#
# // Function to find Node with minimum value in a BST
# Node* FindMin(Node* root) {
#     if (root == NULL)
#         return NULL;
#     while (root->left != NULL)
#         root = root->left;
#     return root;
# }
#
# // Function to find Inorder Successor in a BST
# Node* GetSuccessor(Node* root, int data) {
#     // Search the Node - O(h)
#     Node* current = Find(root, data);
#     if (current == NULL)
#         return NULL;
#     if (current->right != NULL) { // Case 1: Node has right subtree
#         return FindMin(current->right); // O(h)
#     } else { // Case 2: No right subtree  - O(h)
#         Node* successor = NULL;
#         Node* ancestor = current->parent;
#         while (ancestor != NULL && current == ancestor->right) {
#             current = ancestor;
#             ancestor = ancestor->parent;
#         }
#         return ancestor;
#     }
# }
#
# // Function to visit nodes in Inorder
# void Inorder(Node* root) {
#     if (root == NULL)
#         return;
#     Inorder(root->left);       // Visit left subtree
#     cout << root->data << " "; // Print data
#     Inorder(root->right);      // Visit right subtree
# }
#
# // Function to Insert Node in a Binary Search Tree
# Node* Insert(Node* root, int data, Node* parent) {
#     if (root == NULL) {
#         root = new Node();
#         root->data = data;
#         root->left = root->right = NULL;
#         root->parent = parent;
#     } else if (data <= root->data) {
#         root->left = Insert(root->left, data, root);
#     } else {
#         root->right = Insert(root->right, data, root);
#     }
#     return root;
# }
#
# int main() {
#     Node* root = NULL;
#     root = Insert(root, 5, NULL);
#     root = Insert(root, 10, root);
#     root = Insert(root, 3, root);
#     root = Insert(root, 4, root);
#     root = Insert(root, 1, root);
#     root = Insert(root, 11, root);
#
#     // Print Nodes in Inorder
#     cout << "Inorder Traversal: ";
#     Inorder(root);
#     cout << "\n";
#
#     // Find Inorder successor of some node.
#     Node* successor = GetSuccessor(root, 1);
#     if (successor == NULL)
#         cout << "No successor Found\n";
#     else
#         cout << "Successor is " << successor->data << "\n";
# }
